# %%
import torch
import make_data
import run_models

# %%
def get_target_function(x):
        # True function is x * sin(x + 5)
        return x*torch.sin(x+5)
x, y = make_data.make_initial_data(get_target_function)
x_test, y_test, y_perfect = make_data.make_test_data(get_target_function)

# %%
reused_params = {"x": x, "y": y, "x_test": x_test, "y_test": y_test, "y_perfect": y_perfect,
                 "function_type": "xsin(x+5)", "figsize": (4, 4), "samples": 500}

# %%
param_set = [
    {"model_type": "bnn_variational_pyro", "dropout_prob": 0, "epochs": 20000, "samples": 500, "width": 100, "depth": 2},
]
for set in param_set:
    set.update(reused_params)

# %%
"""
for set in param_set:
    run_models.run_model(**set)

param_set = [
    {"model_type": "bnn_variational_pyro", "dropout_prob": 0, "epochs": 20000, "width": 100, "depth": 2},
    {"model_type": "bnn_variational_pyro", "dropout_prob": 0, "epochs": 4000, "width": 100, "depth": 5},
    {"model_type": "bnn_variational_pyro", "dropout_prob": 0, "epochs": 4000, "width": 100, "depth": 10},
    {"model_type": "bnn_variational_pyro", "dropout_prob": 0, "epochs": 20000, "width": 100, "depth": 2},
    {"model_type": "bnn_variational_pyro", "dropout_prob": 0, "epochs": 4000, "width": 100, "depth": 2},
    {"model_type": "bnn_variational_pyro", "dropout_prob": 0, "epochs": 4000, "width": 500, "depth": 2},
]
for set in param_set:
    set.update(reused_params)
"""
# Out:
# '\nfor set in param_set:\n    run_models.run_model(**set)\n\nparam_set = [\n    {"model_type": "bnn_variational_pyro", "dropout_prob": 0, "epochs": 20000, "width": 100, "depth": 2},\n    {"model_type": "bnn_variational_pyro", "dropout_prob": 0, "epochs": 4000, "width": 100, "depth": 5},\n    {"model_type": "bnn_variational_pyro", "dropout_prob": 0, "epochs": 4000, "width": 100, "depth": 10},\n    {"model_type": "bnn_variational_pyro", "dropout_prob": 0, "epochs": 20000, "width": 100, "depth": 2},\n    {"model_type": "bnn_variational_pyro", "dropout_prob": 0, "epochs": 4000, "width": 100, "depth": 2},\n    {"model_type": "bnn_variational_pyro", "dropout_prob": 0, "epochs": 4000, "width": 500, "depth": 2},\n]\nfor set in param_set:\n    set.update(reused_params)\n'

# %%
param_set = [
    {"model_type": "bnn_variational_pyro", "dropout_prob": 0, "epochs": 4000, "width": 5, "depth": 2},
    {"model_type": "bnn_variational_pyro", "dropout_prob": 0, "epochs": 4000, "width": 10, "depth": 2},
    {"model_type": "bnn_variational_pyro", "dropout_prob": 0, "epochs": 4000, "width": 20, "depth": 2},
]
for set in param_set:
    set.update(reused_params)

# %%
for set in param_set:
    run_models.run_model(**set)

# %%
param_set = [
    {"model_type": "bnn_variational", "dropout_prob": 0.1, "epochs": 4000, "width": 5, "depth": 2},
    {"model_type": "bnn_variational", "dropout_prob": 0.1, "epochs": 4000, "width": 10, "depth": 2},
    {"model_type": "bnn_variational", "dropout_prob": 0.1, "epochs": 4000, "width": 20, "depth": 2},
    {"model_type": "bnn_variational", "dropout_prob": 0.1, "epochs": 4000, "width": 100, "depth": 2},
    {"model_type": "bnn_variational", "dropout_prob": 0.1, "epochs": 4000, "width": 100, "depth": 5},
    {"model_type": "bnn_variational", "dropout_prob": 0.1, "epochs": 4000, "width": 100, "depth": 10},
    {"model_type": "bnn_variational", "dropout_prob": 0, "epochs": 4000, "width": 100, "depth": 2},
    {"model_type": "bnn_variational", "dropout_prob": 0.5, "epochs": 4000, "width": 100, "depth": 2},
    {"model_type": "bnn_variational", "dropout_prob": 0.1, "epochs": 10000, "width": 100, "depth": 2},
    {"model_type": "bnn_variational", "dropout_prob": 0.1, "epochs": 4000, "width": 500, "depth": 2},
]
for set in param_set:
    set.update(reused_params)

# %%
for set in param_set:
    run_models.run_model(**set)
# Out:
# 0 / 4000
# 500 / 4000
# 1000 / 4000
# 1500 / 4000
# 2000 / 4000
# 2500 / 4000
# 3000 / 4000
# 3500 / 4000
# 0 / 4000
# 500 / 4000
# 1000 / 4000
# 1500 / 4000
# 2000 / 4000
# 2500 / 4000
# 3000 / 4000
# 3500 / 4000
# 0 / 4000
# 500 / 4000
# 1000 / 4000
# 1500 / 4000
# 2000 / 4000
# 2500 / 4000
# 3000 / 4000
# 3500 / 4000
# 0 / 4000
# 500 / 4000
# 1000 / 4000
# 1500 / 4000
# 2000 / 4000
# 2500 / 4000
# 3000 / 4000
# 3500 / 4000
# 0 / 4000
# 500 / 4000
# 1000 / 4000
# 1500 / 4000
# 2000 / 4000
# 2500 / 4000
# 3000 / 4000
# 3500 / 4000
# 0 / 4000
# 500 / 4000
# 1000 / 4000
# 1500 / 4000
# 2000 / 4000
# 2500 / 4000
# 3000 / 4000
# 3500 / 4000
# 0 / 4000
# 500 / 4000
# 1000 / 4000
# 1500 / 4000
# 2000 / 4000
# 2500 / 4000
# 3000 / 4000
# 3500 / 4000
# 0 / 4000
# 500 / 4000
# 1000 / 4000
# 1500 / 4000
# 2000 / 4000
# 2500 / 4000
# 3000 / 4000
# 3500 / 4000
# 0 / 10000
# 500 / 10000
# 1000 / 10000
# 1500 / 10000
# 2000 / 10000
# 2500 / 10000
# 3000 / 10000
# 3500 / 10000
# 4000 / 10000
# ...

# %%
param_set = [{"model_type": "bnn_MCMC", "epochs": 50, "width": 20, "depth": 2, "reverse_plot":True},
             {"model_type": "bnn_MCMC", "epochs": 50, "width": 50, "depth": 2, "reverse_plot":True},
             {"model_type": "bnn_MCMC", "epochs": 50, "width": 20, "depth": 2, "reverse_plot":True},
             {"model_type": "bnn_MCMC", "epochs": 50, "width": 20, "depth": 5, "reverse_plot":True},
              {"model_type": "bnn_MCMC", "epochs": 50, "width": 20, "depth": 10, "reverse_plot":True},
              {"model_type": "bnn_MCMC", "epochs": 200, "width": 20, "depth": 2, "reverse_plot":True}]
for set in param_set:
    set.update(reused_params)

# %%
for set in param_set:
    run_models.run_model(**set)
# Out:
# ...
# Warmup:  39%|▊ | 157/400 [06:19,  2.67s/it, step size=5.23e-03, acc. prob=0.789]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 for set in param_set:
# ----> 2     run_models.run_model(**set)
#
# File ~/Documents/University_Work/Year4/Uncertainty_Quant/Project3/run_models.py:21, in run_model(x, y, x_test, y_test, y_perfect, model_type, function_type, dropout_prob, epochs, samples, mu, sigma, width, depth, reverse_plot, figsize)
#      19 elif model_type=="bnn_MCMC":
#      20     model = pyro_bayesian.BNN(hid_dim=width, n_hid_layers=depth)
# ---> 21     mcmc = pyro_bayesian.train_pyro_model(model, x, y, num_samples=epochs)
#      22     mean_values, std_values = pyro_bayesian.get_dist(model, mcmc, x_test)
#      23 elif model_type=="bnn_variational_pyro":
#
# ...

# %%
param_set = [
    {"model_type": "gaussian_process", "epochs": 10},
    {"model_type": "gaussian_process", "epochs": 50},
    {"model_type": "gaussian_process", "epochs": 100},]
for set in param_set:
    set.update(reused_params)

# %%
for set in param_set:
    run_models.run_model(**set)
# Out:
# /home/jasmine/miniforge3/envs/uncertainty_quant/lib/python3.12/site-packages/gpytorch/models/exact_gp.py:284: GPInputWarning: The input matches the stored training data. Did you forget to call model.train()?
#   warnings.warn(

# %%
param_set = [
    {"model_type": "standard_nn", "dropout_prob": 0.1, "epochs": 4000, "width": 100, "depth": 2},
    {"model_type": "standard_nn", "dropout_prob": 0.1, "epochs": 4000, "width": 100, "depth": 5},
    {"model_type": "standard_nn", "dropout_prob": 0.1, "epochs": 4000, "width": 100, "depth": 10},
    {"model_type": "standard_nn", "dropout_prob": 0, "epochs": 4000, "width": 100, "depth": 2},
    {"model_type": "standard_nn", "dropout_prob": 0.5, "epochs": 4000, "width": 100, "depth": 2},
    {"model_type": "standard_nn", "dropout_prob": 0.1, "epochs": 10000, "width": 100, "depth": 2},
    {"model_type": "standard_nn", "dropout_prob": 0.1, "epochs": 4000, "width": 500, "depth": 2},
]
param_set = [
    {"model_type": "standard_nn", "dropout_prob": 0.1, "epochs": 200, "width": 20, "depth": 2},
    {"model_type": "standard_nn", "dropout_prob": 0, "epochs": 200, "width": 20, "depth": 2},
]
for set in param_set:
    set.update(reused_params)

# %%
for set in param_set:
    run_models.run_model(**set)

# %%
param_set = [
    {"model_type": "bnn_variational", "dropout_prob": 0.1, "epochs": 4000, "width": 100, "depth": 2, "sigma":0.05},
    {"model_type": "bnn_variational", "dropout_prob": 0.1, "epochs": 4000, "width": 100, "depth": 2, "sigma":0.3},
    {"model_type": "bnn_variational", "dropout_prob": 0.1, "epochs": 4000, "width": 100, "depth": 2, "sigma":1},
    {"model_type": "bnn_variational", "dropout_prob": 0.1, "epochs": 4000, "width": 100, "depth": 2, "mu":2},
]
for set in param_set:
    set.update(reused_params)

# %%
for set in param_set:
    run_models.run_model(**set)
